# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import numpy as np 
import seaborn as sns 
import folium
from datetime import datetime, timedelta

import pandas as pd
import geopandas as gpd
import plotly.express as px
import plotly.graph_objects as go

# %%
# load excel dataset
raw_data = pd.read_excel(
    '/Users/tish/Documents/Flexible Masters/02806 - Social data and visualization/CODE_Social_data_Visialization/TishDuc.github.io/Displacements_Final_Project/Data/UNHCR_Flow_Data.xlsx',
    sheet_name='DATA'
)

# display the first 10 rows of the dataset
raw_data[:10]
# Out:
#   origin OriginISO              OriginName asylum AsylumISO  \
# 0    ALG       DZA                 Algeria    MTA       MLT
# 1    ANG       AGO                  Angola    COD       COD
# 2    ANG       AGO                  Angola    NAM       NAM
# 3    BDI       BDI                 Burundi    NAM       NAM
# 4    CHI       CHN                   China    NEP       NPL
# 5    COB       COG      Congo, Republic of    NAM       NAM
# 6    COD       COD  Dem. Rep. of the Congo    NAM       NAM
# 7    IRQ       IRQ                    Iraq    MTA       MLT
# 8    SOM       SOM                 Somalia    NAM       NAM
# 9    SUD       SDN                   Sudan    MTA       MLT
#
#                AsylumName                 AsylumRegion Population types  Year  \
# 0                   Malta                       Europe              REF  1962
# 1  Dem. Rep. of the Congo      West and Central Africa              REF  1962
# 2                 Namibia  Eastern and Southern Africa              REF  1962
# 3                 Namibia  Eastern and Southern Africa              REF  1962
# 4                   Nepal         Asia and the Pacific              REF  1962
# 5                 Namibia  Eastern and Southern Africa              REF  1962
# 6                 Namibia  Eastern and Southern Africa              REF  1962
# 7                   Malta                       Europe              REF  1962
# 8                 Namibia  Eastern and Southern Africa              REF  1962
# 9                   Malta                       Europe              REF  1962
#
#    Count
# 0      5
# 1  20000
# 2    277
# 3     13
# 4      5
# 5      8
# 6     13
# 7     17
# 8      5
# 9     10

# %%
print(raw_data.shape)
# Out:
# (107341, 10)

# %%
# --------------------------------------
#       changes to the raw data 
# --------------------------------------

#      Casing
# ------------------
# header to lowercase
raw_data.columns = raw_data.columns.str.lower()
# data to lowercase
for col in raw_data.select_dtypes(include='object'):
    raw_data[col] = raw_data[col].str.lower()

# check for duplicates
# ---------------------
print("number of duplicates found:", raw_data.duplicated().sum()) # ----> 0 duplicates

# check for missing values
# ---------------------
print(raw_data.isnull().sum())
# remove rows with missing values
raw_data = raw_data.dropna()
# Sanity check it worked:
# print(raw_data.isnull().sum())

raw_data[:20]
# Out:
# number of duplicates found: 0
# origin               0
# originiso            0
# originname          35
# asylum               0
# asylumiso            0
# asylumname           0
# asylumregion        37
# population types     0
# year                 0
# count                0
# dtype: int64
#    origin originiso              originname asylum asylumiso  \
# 0     alg       dza                 algeria    mta       mlt
# 1     ang       ago                  angola    cod       cod
# 2     ang       ago                  angola    nam       nam
# 3     bdi       bdi                 burundi    nam       nam
# 4     chi       chn                   china    nep       npl
# 5     cob       cog      congo, republic of    nam       nam
# 6     cod       cod  dem. rep. of the congo    nam       nam
# 7     irq       irq                    iraq    mta       mlt
# 8     som       som                 somalia    nam       nam
# 9     sud       sdn                   sudan    mta       mlt
# 11    ang       ago                  angola    cod       cod
# 12    are       egy                   egypt    leb       lbn
# 13    rom       rou                 romania    leb       lbn
# 14    rwa       rwa                  rwanda    bdi       bdi
# 15    rwa       rwa                  rwanda    cod       cod
# 16    rwa       rwa                  rwanda    uga       uga
# 17    sud       sdn                   sudan    cod       cod
# 18    sud       sdn                   sudan    uga       uga
# 20    ang       ago                  angola    cod       cod
# 21    arm       arm                 armenia    are       egy
#
#                 asylumname                  asylumregion population types  \
# 0                    malta                        europe              ref
# 1   dem. rep. of the congo       west and central africa              ref
# 2                  namibia   eastern and southern africa              ref
# 3                  namibia   eastern and southern africa              ref
# 4                    nepal          asia and the pacific              ref
# 5                  namibia   eastern and southern africa              ref
# 6                  namibia   eastern and southern africa              ref
# 7                    malta                        europe              ref
# 8                  namibia   eastern and southern africa              ref
# 9                    malta                        europe              ref
# 11  dem. rep. of the congo       west and central africa              ref
# 12                 lebanon  middle east and north africa              ref
# 13                 lebanon  middle east and north africa              ref
# 14                 burundi   eastern and southern africa              ref
# 15  dem. rep. of the congo       west and central africa              ref
# 16                  uganda   eastern and southern africa              ref
# 17  dem. rep. of the congo       west and central africa              ref
# 18                  uganda   eastern and southern africa              ref
# 20  dem. rep. of the congo       west and central africa              ref
# 21                   egypt  middle east and north africa              ref
#
#     year  count
# 0   1962      5
# 1   1962  20000
# 2   1962    277
# 3   1962     13
# 4   1962      5
# 5   1962      8
# 6   1962     13
# 7   1962     17
# 8   1962      5
# 9   1962     10
# 11  1963   5000
# 12  1963    160
# 13  1963     70
# 14  1963   4000
# 15  1963   1000
# 16  1963   2000
# 17  1963   8000
# 18  1963   5000
# 20  1964  25000
# 21  1964     90

# %%
# ---------------------------------------------------------------
#                  A closer look at the countries
# ---------------------------------------------------------------

#########################
# QUESTION: 
# should we remove 'unknown/other'?? is that missing data or an appearing country?
#########################

#---------------------------------
#.    unique origin countries
#---------------------------------
# total name and number
unique_origin_countries = raw_data['originname'].unique()
print("Total unique origin countries:", len(unique_origin_countries))
# print("Unique origin countries:", unique_origin_countries[:10]) # print first 10 unique origin countries

# year of the first and last mention of each country in the origin column
first_mention_origin_country = raw_data.groupby('originname')['year'].min()
last_mention_origin_country = raw_data.groupby('originname')['year'].max()

#---------------------------------
#   unique destination countries
#---------------------------------
# total name and number
unique_destination_countries = raw_data['asylumname'].unique()
print("Total unique destination countries:", len(unique_destination_countries))
# print("Unique destination countries:", unique_destination_countries[:10]) # print first 10 unique destination countries

# year of the first and last mention of each country in the destination column
first_mention_destination_country = raw_data.groupby('asylumname')['year'].min()
last_mention_destination_country = raw_data.groupby('asylumname')['year'].max()

#---------------------------------
#       unique country names
#---------------------------------
unique_countries = set(unique_origin_countries).union(set(unique_destination_countries))
print("Total unique countries (origin + destination):", len(unique_countries))
print("Unique countries (origin + destination):", list(unique_countries)[:10]) # print first 10 unique countries (origin + destination)

# find the 3 countries that are only in the destination column and not in the origin column
only_destination_countries = set(unique_destination_countries) - set(unique_origin_countries)
print("Countries that are only in the destination column", only_destination_countries)

# line plot 
# x = time in years
# y = name of the country
# each line is a country, 
# and the line starts at the first year it is mentioned and ends at the last year it is mentioned


#---------------------------------
#   combine origin + destination
#---------------------------------
first_mention_country = pd.concat([
    first_mention_origin_country,
    first_mention_destination_country
], axis=1).min(axis=1)

last_mention_country = pd.concat([
    last_mention_origin_country,
    last_mention_destination_country
], axis=1).max(axis=1)

# combine first and last year into one dataframe
country_years = pd.DataFrame({
    'country': first_mention_country.index,
    'start': first_mention_country.values,
    'end': last_mention_country.values
})


#---------------------------------
#               plot
#---------------------------------
plt.figure(figsize=(12, 40))

for i, row in country_years.iterrows():
    plt.plot(
        [row['start'], row['end']],
        [i, i],
        color='blue',
        alpha=0.6,
        linewidth=2
    )

plt.yticks(range(len(country_years)), country_years['country'])
plt.xlabel('Year')
plt.ylabel('Country')
plt.yticks(range(len(country_years)), country_years['country'], fontsize=9)
plt.title('First and Last Appearance of Countries')

plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Total unique origin countries: 213
# Total unique destination countries: 189
# Total unique countries (origin + destination): 216
# Unique countries (origin + destination): ['madagascar', 'tonga', 'niue', 'sudan', "dem. people's rep. of korea", 'mauritania', 'dominican rep.', 'algeria', 'seychelles', 'uganda']
# Countries that are only in the destination column {'sint maarten (dutch part)', 'british virgin islands', 'aruba'}

# %%
# hard to tell ....low data reliability between 1960 ....1990 ish .... "creations of countries" VS "oh we just started counting more migration"

# %%
# find first time serbia ismentionned
serbia_first_year = raw_data[raw_data['origin'] == 'srb']['year'].min()
print("Serbia first mentioned in:", serbia_first_year)
# last time serbia is mentioned
serbia_last_year = raw_data[raw_data['origin'] == 'srb']['year'].max()
print("Serbia last mentioned in:", serbia_last_year)

# find time when slovenia is mentioned
slovenia_first_year = raw_data[raw_data['originname'] == 'slovenia']['year'].min()
print("Slovenia first mentioned in:", slovenia_first_year)

# first time "Russian Federation" is mentioned
russia_first_year = raw_data[raw_data['originname'] == 'russian federation']['year'].min()
print("Russian Federation first mentioned in:", russia_first_year)

# last time "Russian Federation" is mentioned
russia_last_year = raw_data[raw_data['originname'] == 'russian federation']['year'].max()
print("Russian Federation last mentioned in:", russia_last_year)    

# last time "yugoslavia" is mentioned
yugoslavia_last_year = raw_data[raw_data['origin'] == 'yu']['year'].max()
print("Yugoslavia last mentioned in:", yugoslavia_last_year)    

# montenegro
yugoslavia_first_year = raw_data[raw_data['origin'] == 'mne']['year'].min()
print("firet mention of montenegro", yugoslavia_first_year)

# first time "timor" is mentioned
timor_first_year = raw_data[raw_data['originname'] == 'timor-leste']['year'].min()
print("Timor-Leste first mentioned in:", timor_first_year)
# Out:
# Serbia first mentioned in: 1970
# Serbia last mentioned in: 2025
# Slovenia first mentioned in: 1992
# Russian Federation first mentioned in: 1966
# Russian Federation last mentioned in: 2025
# Yugoslavia last mentioned in: nan
# firet mention of montenegro 2006
# Timor-Leste first mentioned in: 1999

# %%
# deal with annoyinhg names :

"Côte d'Ivoire", "Iran (Islamic Rep. of)", "Netherlands (Kingdom of the)", "State of Palestine", 
"Lao People's Dem. Rep" = "Laos"

"Dem. Rep. of the Congo" VS "Congo, Republic of"
# Out:
#   Cell In[8], line 4
#     "Lao People's Dem. Rep" = "Laos"
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
# date the first time a country of origin appears in the dataset
first_country_appearance = raw_data.groupby('originname')['year'].min()
print(first_country_appearance)
# Out:
# originname
# afghanistan       1972
# albania           1965
# algeria           1962
# andorra           1989
# angola            1962
#                   ...
# viet nam          1966
# western sahara    1987
# yemen             1970
# zambia            1968
# zimbabwe          1972
# Name: year, Length: 213, dtype: int64

# %%
# --------------------------------------
# filter data
# --------------------------------------

flow_data = raw_data.copy()

flow_data = flow_data[flow_data['year'] == 2024]
flow_data = flow_data[flow_data['population types'] == 'ref']

flow_data = (
    flow_data
    .groupby(['originiso', 'asylumiso'], as_index=False)['count']
    .sum()
    .sort_values('count', ascending=False)
    .head(100)
)

# --------------------------------------
# get country centroids
# --------------------------------------

url = "https://naturalearth.s3.amazonaws.com/110m_cultural/ne_110m_admin_0_countries.zip"
world = gpd.read_file(url)

world = world[['ADM0_A3', 'ADMIN', 'geometry']].copy()
world = world.rename(columns={'ADM0_A3': 'iso_a3', 'ADMIN': 'name'})
world = world[world['iso_a3'] != '-99'].copy()

world_proj = world.to_crs('+proj=robin')
world['centroid'] = world_proj.geometry.centroid.to_crs(world.crs)
world['lon'] = world['centroid'].x
world['lat'] = world['centroid'].y

centroids = world[['iso_a3', 'lat', 'lon']].copy()

origin_coords = centroids.rename(columns={
    'iso_a3': 'originiso',
    'lat': 'origin_lat',
    'lon': 'origin_lon'
})

asylum_coords = centroids.rename(columns={
    'iso_a3': 'asylumiso',
    'lat': 'asylum_lat',
    'lon': 'asylum_lon'
})

flow_data = flow_data.merge(origin_coords, on='originiso', how='left')
flow_data = flow_data.merge(asylum_coords, on='asylumiso', how='left')
flow_data = flow_data.dropna()

# --------------------------------------
# build plotly flow map
# --------------------------------------

fig = go.Figure()

max_count = flow_data['count'].max()

for _, row in flow_data.iterrows():
    fig.add_trace(go.Scattergeo(
        lon=[row['origin_lon'], row['asylum_lon']],
        lat=[row['origin_lat'], row['asylum_lat']],
        mode='lines',
        line=dict(width=max(1, row['count'] / max_count * 8)),
        opacity=0.35,
        hoverinfo='text',
        text=f"{row['originiso']} → {row['asylumiso']}<br>Count: {row['count']}"
    ))

fig.update_layout(
    title='Refugee flows by country',
    showlegend=False,
    geo=dict(
        projection_type='natural earth',
        showland=True,
        landcolor='rgb(230, 230, 230)',
        showcountries=True
    ),
    margin=dict(l=0, r=0, t=40, b=0)
)

fig.show()
